# %% [markdown]
# 画损失函数曲线等等

# %%
import matplotlib.pyplot as plt

# 假设这是你从训练中记录下的每一轮的 Loss
loss_values = [
    0.6743, 0.6183, 0.4110, 0.2173, 0.0962,
    0.0874, 0.0730, 0.0717, 0.0678, 0.0679,
    0.0654, 0.0667, 0.0618, 0.0598, 0.0573,
    0.0554, 0.0562, 0.0532, 0.0495, 0.0482
]

epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, loss_values, marker='o', linestyle='-', color='b')
plt.title('Training Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.xticks(epochs)
plt.show()

# %%
import matplotlib.pyplot as plt

# 提供的损失函数数据
loss_data = [
    55.807278, 52.307710, 50.766000, 50.458580, 49.921465, 48.903329, 45.970545, 43.345099,
    41.385102, 39.644357, 37.761686, 34.511197, 31.962008, 30.872616, 29.579944, 29.068527,
    27.964916, 27.400173, 26.382283, 25.899307, 25.270587, 25.099583, 25.927315, 25.001130,
    24.238625, 24.302087, 23.399055, 23.117731, 22.883856, 22.295845, 21.747166, 21.437371,
    20.718690, 20.496933, 20.463230, 20.617534, 19.827911, 19.565586, 19.498368, 19.177333,
    18.917181, 18.086953, 17.802391, 17.873319, 17.551933, 17.680483, 17.909415, 17.494265,
    17.289605, 17.346526, 17.082393, 17.217948, 16.455817, 16.441791, 16.546623, 16.577146,
    15.850205, 15.772520, 15.827906, 15.629402, 15.265027, 15.359270, 15.060013, 15.482174,
    15.463940, 15.285734, 15.095143, 15.005053, 15.525516, 15.022083, 14.769059, 14.750371,
    14.409799, 14.495130, 14.842247, 14.572606, 14.613181, 14.221691, 14.149220, 14.155971,
    14.205580, 13.877332, 14.376100, 14.447904, 14.273804, 14.244321, 13.827223, 13.723666,
    13.886716, 13.770707, 13.749940, 13.683287, 13.617915, 13.595077, 13.277423, 13.592493,
    13.422504, 13.342397, 13.391093, 13.776302
]

# 生成 Epoch 编号
epochs = range(1, len(loss_data) + 1)

# 绘制损失函数曲线
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss_data, marker='o', linestyle='-', color='b')
plt.title('Training Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.xticks(epochs[::5])  # 每隔 5 个 Epoch 显示一个刻度
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 提供的新的损失函数数据
loss_data_new = [
    72.902134, 67.837521, 65.673551, 64.834325, 63.463741, 60.678510, 54.686833, 50.355443,
    47.270206, 41.166245, 36.490553, 34.827471, 33.923642, 32.901653, 32.119028, 31.830541,
    31.353225, 30.726900, 30.021338, 29.703969, 29.313847, 28.902132, 28.519739, 28.100367,
    27.647879, 26.860981, 27.088290, 26.295251, 25.582685, 25.500436, 24.802159, 24.336269,
    23.889621, 23.575949, 23.141856, 23.093336, 22.932294, 22.433013, 22.280926, 22.032044,
    21.788519, 21.513140, 21.279622, 20.536958, 20.068901, 20.029006, 20.272379, 19.612384,
    20.215368, 19.941127, 18.939773, 18.875567, 18.769498, 17.980482, 17.881179, 18.261754,
    18.627280, 18.140419, 17.283946, 17.302308, 17.450152, 17.023443, 16.475741, 16.422787,
    16.518923, 16.286152, 16.432652, 16.427701, 16.178713, 16.001213, 16.063947, 15.843773,
    15.396173, 15.810812, 15.890443, 15.505257, 15.266937, 15.167411, 15.142315, 14.940145,
    14.948639, 14.655773, 14.746506, 14.747266, 14.695975, 14.807708, 14.484942, 14.365326,
    14.201862, 14.412018, 14.273935, 14.161277, 13.984699, 14.033252, 14.341371, 14.161383,
    13.643874, 13.671217, 13.667473, 13.397310
]

# 生成 Epoch 编号
epochs_new = range(1, len(loss_data_new) + 1)

# 绘制新的损失函数曲线
plt.figure(figsize=(10, 6))
plt.plot(epochs_new, loss_data_new, marker='o', linestyle='-', color='r')
plt.title('Training Loss Curve (Second Run)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.xticks(epochs_new[::5])  # 每隔 5 个 Epoch 显示一个刻度
plt.tight_layout()
plt.show()
